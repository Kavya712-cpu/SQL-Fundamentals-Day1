# %%
import pandas as pd
import plotly.express as px

print("W7D3 Plotly setup successful")
# Out:
# W7D3 Plotly setup successful

# %%
# %pip install plotly
# Out:
# Collecting plotly
#   Using cached plotly-6.9.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\charan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from plotly) (2.20.0)
# Requirement already satisfied: packaging in c:\users\charan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from plotly) (26.0)
# Using cached plotly-6.9.0-py3-none-any.whl (9.9 MB)
# Installing collected packages: plotly
# Successfully installed plotly-6.9.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.2.1
# [notice] To update, run: C:\Users\Charan\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import plotly.express as px

print("Plotly installed successfully")
# Out:
# Plotly installed successfully

# %%
import plotly.express as px

data = {
    "Category": ["A", "B", "C", "D"],
    "Sales": [100, 150, 120, 180]
}

fig = px.bar(data, x="Category", y="Sales", title="Sales by Category")
fig.show()

# %%
# %pip install nbformat
# Out:
# Collecting nbformat
#   Downloading nbformat-5.11.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting fastjsonschema>=2.15 (from nbformat)
#   Downloading fastjsonschema-2.22.2-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\charan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nbformat) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\charan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nbformat) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in c:\users\charan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nbformat) (5.16.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\charan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema>=2.6->nbformat) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\charan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema>=2.6->nbformat) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\charan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema>=2.6->nbformat) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\charan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema>=2.6->nbformat) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\charan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.11.1)
# Requirement already satisfied: typing-extensions>=4.4.0 in c:\users\charan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat) (4.15.0)
# Downloading nbformat-5.11.1-py3-none-any.whl (79 kB)
#    ---------------------------------------- 0.0/79.8 kB ? eta -:--:--
#    ---------------------------------------- 0.0/79.8 kB ? eta -:--:--
#    ----- ---------------------------------- 10.2/79.8 kB ? eta -:--:--
#    ------------------------------ --------- 61.4/79.8 kB 825.8 kB/s eta 0:00:01
#    ---------------------------------------- 79.8/79.8 kB 638.6 kB/s eta 0:00:00
# Downloading fastjsonschema-2.22.2-py3-none-any.whl (27 kB)
# Installing collected packages: fastjsonschema, nbformat
# Successfully installed fastjsonschema-2.22.2 nbformat-5.11.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.2.1
# [notice] To update, run: C:\Users\Charan\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import plotly.express as px

data = {
    "Category": ["Food", "Travel", "Shopping"],
    "Amount": [500, 800, 600]
}

fig = px.bar(data, x="Category", y="Amount", title="Expense by Category")
fig.show()
